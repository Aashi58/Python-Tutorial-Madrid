# %%
#tuple constructor
t1=12,23,24,25,26,56
a,b,c,d,e,f=t1
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# 12
# 23
# 24
# 25
# 26
# 56

# %%
t2=(11)
print(type(t2))
# Out:
# <class 'int'>

# %%
t2=(11,)
print(type(t2))
# Out:
# <class 'tuple'>

# %%
#accessing
t1=(12,23,24,26,46,78)
print(t1[0])
print(t1[3])
print(t1[-1])
print(t1[-2])
# Out:
# 12
# 26
# 78
# 46

# %%
#updateing
t1=(12,23,25,56)
t2=('how','are')
print(t1+t2)
# Out:
# (12, 23, 25, 56, 'how', 'are')

# %%
#index method
t1=(12,23,24,26,46,78)
print(t1)
x=t1.index(23)
print(x)
# Out:
# (12, 23, 24, 26, 46, 78)
# 1

# %%
del t1
print(t1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8fed61a84154> in <cell line: 2>()
#       1 del t1
# ----> 2 print(t1)
#
# NameError: name 't1' is not defined
