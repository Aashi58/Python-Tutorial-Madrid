# %%
# if
n=int(input('enter the number'))
if n==10:
  print('you won')
# Out:
# enter the number10
# you won

# %%
n=int(input('enter the number'))
if n<0:
  print('-ve number')
if n>0:
  print('+ve number')
if n==0:
  print('number is zero')
# Out:
# enter the number0
# number is zero

# %%
n=int(input('enter the number'))
if n%2==0:
  print('even number')
else:
  print('odd number')
# Out:
# enter the number7
# odd number

# %%
year=int(input('enter the year'))
if year%4==0:
  print('leap year')
else:
  print('non leap year')
# Out:
# enter the year8
# leap year

# %%
age=int(input("enter the age"))
if age>=18:
  print("elligible to vote")
else:
  print("not elligible to vote")
# Out:
# enter the age12
# not elligible to vote

# %%
day=int(input("enter the number from 1--7"))
if day==1:
  print("sun")
elif day==2:
  print("mon")
elif day==3:
  print("tue")
elif day==4:
  print("wed")
elif day==5:
  print("thu")
elif day==6:
  print("fri")
elif day==7:
  print("sat")
# Out:
# enter the number from 1--72
# mon

# %%
p=float(input('enter the marks'))
c=float(input('enter the marks'))
m=float(input('enter the marks'))
e=float(input('enter the marks'))
h=float(input('enter the marks'))
s=p+c+m+e+h
per=s*100/500
if per>=60:
  print('first division')
if per>=45:
  print('second division')
if per>=33:
  print('third division')
else:
  print('fail')
# Out:
# enter the marks44
# enter the marks65
# enter the marks25
# enter the marks98
# enter the marks66
# second division
# third division

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
c=int(input("enter the number"))
if a>b and a>c:
  print("a is greatest")
elif b>a and b>c:
  print("b is grestest")
else:
  print("c is greatest")
# Out:
# enter the number45
# enter the number78
# enter the number56
# b is grestest

# %%
#logical funtion
#and
a=int(input('enter the number'))
b=int(input('enter the number'))
c=int(input('enter the number'))
if a>b and b>c:
  print('a is greatest')
elif b>a and b>c:
  print('b is greatest')
else:
  print('c is greatest')
# Out:
# enter the number20
# enter the number55
# enter the number65
# c is greatest

# %%
# or
#check vowel and consonant
ch=input('enter the alphabet without space')
if ch=='a'or ch=='e'or ch=='i'or ch=='o'or ch=='u':
  print('vowel')
elif ch=='A'or ch=='E'or ch=="I"or ch=='O'or ch=='U':
  print('vowel')
else:
  print('consonant')
# Out:
# enter the alphabet without spaceP
# consonant

# %%
# traffic light programme
ch=input("enter the alphabet \n r for red \n g for green \n y for yellow \n")
if ch=='r' or ch=='R':
  print("stop")
elif ch=='y' or ch=='Y':
  print("get ready")
elif ch=='g' or ch=='G':
  print("go forward")
else:
  print("pay chalaan")
# Out:
# enter the alphabet
#  r for red
#  g for green
#  y for yellow
# U
# pay chalaan

# %%
#MINI CALCULATOR
a=int(input("enter the number"))
b=int(input("enter the number"))
print("1.add")
print("2.sub")
print("3.mul")
print("4.div")
choice=int(input("enter the choice from above"))
if choice==1:
  print("the sum is",a+b)
elif choice==2:
  print("the sum is",a-b)
elif choice==3:
  print("the sum is",a*b)
elif choice==4:
  print("the sum is",a/b)
else:
  print("invalid choice")
# Out:
# enter the number20
# enter the number65
# 1.add
# 2.sub
# 3.mul
# 4.div
# enter the choice from above2
# the sum is -45

# %%
# IN MENBERSHIP OPERATOR
print('a' in ['a'or'e'or'i'or'o'or'u' ])
# Out:
# True

# %%
#meter bill
amt=0
nu=int(input('enter the number of units'))
if nu<=100:
  amt=0
elif nu>100:
  amt=(nu-100)*5
elif nu>200:
  amt=500+(nu-200)*10
print('amount to pay:',amt)
# Out:
# enter the number of units500
# amount to pay: 2000

# %%
# absolute number
number=int(input('enter the number'))
print('enter the number')
if number<0:
  print(number*-2)
else:
  print('number')
# Out:
# enter the number20
# enter the number
# number

# %%
#abs method
a=int(input('enter the number'))
b=abs(a)
print(b)
# Out:
# enter the number2
# 2

# %%
# TAKE A VALUE OF LENGTH AND BREADTH OF A RECTANGLE FROM USER AND CHECK

print("enter the length")
length=int(input("enter the number"))
print("enter the breadth")
breadth=int(input("enter the number"))
if length==breadth:
  print("yes,it is square")
  print("the area of square is",length**2)
else:
  print("no it is only rectangle")
  print("the area of rectangle is",length*breadth)
# Out:
# enter the length
# enter the number20
# enter the breadth
# enter the number20
# yes,it is square
# the area of square is 400

# %%
# ATTENDANCE FOR EXAMS SEATING
print("number of class held")
noh=int(input("enter the number"))
print("number of class attend")
noa=int(input("enter the number"))
attend=(noa/noh)*100
print("attendance is",attend)
if attend>=75:
  print("you can seat in exam")
else:
  print("you cannot seat in exam")
# Out:
# number of class held
# enter the number1000
# number of class attend
# enter the number10
# attendance is 1.0
# you cannot seat in exam
